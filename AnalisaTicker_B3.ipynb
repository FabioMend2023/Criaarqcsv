# %%
import datetime
import yfinance as yf
import pandas as pd
import matplotlib.pyplot as plt

#ticker = 'AAPL' # Apple
#ticker = '^BVSP' # BOVESPA
Myticker = 'PETR4.SA'
Myticker2 = 'BBPO11.SA'

# Formato de data: Ano, Mes, Dia
start = datetime.datetime(2023,1,1)
end = datetime.datetime(2023,8,16)

# print(start)

# %%
ticker_ohlc = yf.download(Myticker , start , end)
ticker_ohlc2 = yf.download(Myticker2 , start , end)

print("HISTORICO : " + Myticker)
print(ticker_ohlc)

print("HISTORICO : " + Myticker2)
print(ticker_ohlc2)


ticker_ohlc["Adj Close"].plot(figsize=(15,10))
# plt.show()
# Out:
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# HISTORICO : PETR4.SA
#                  Open       High        Low      Close  Adj Close     Volume
# Date
# 2023-01-02  23.540001  23.809999  22.799999  22.920000  18.442509   78424700
# 2023-01-03  22.940001  23.100000  22.129999  22.340000  17.975813   96750300
# 2023-01-04  21.959999  23.590000  21.830000  23.049999  18.547112  129504000
# 2023-01-05  23.340000  24.040001  23.150000  23.879999  19.214968   73886000
# 2023-01-06  23.940001  24.320000  23.549999  23.740000  19.102318   51851500
# ...               ...        ...        ...        ...        ...        ...
# 2023-08-09  30.209999  30.719999  30.160000  30.459999  29.341539   48561500
# 2023-08-10  30.299999  30.860001  30.120001  30.629999  29.505297   54020200
# 2023-08-11  30.610001  31.040001  30.160000  30.559999  29.437868   39403200
# ...

# %%
Myticker_dy = yf.Ticker(Myticker2)
Myhist = Myticker_dy.history(period="max")
Myhist
# Out:
#                                 Open       High        Low      Close  Volume  \
# Date
# 2014-08-06 00:00:00-03:00  88.800922  89.604208  88.610448  89.438583    6503
# 2014-08-07 00:00:00-03:00  89.430301  89.595931  89.024516  89.347488    9636
# 2014-08-08 00:00:00-03:00  89.264688  89.438595  88.701555  89.422035   10161
# 2014-08-11 00:00:00-03:00  89.438588  89.438588  89.065929  89.206711   14846
# 2014-08-12 00:00:00-03:00  89.256406  89.769852  89.065938  89.769852   10946
# ...                              ...        ...        ...        ...     ...
# 2023-08-22 00:00:00-03:00  97.650002  97.910004  97.199997  97.900002   13683
# 2023-08-23 00:00:00-03:00  97.370003  97.930000  97.370003  97.879997   20603
# 2023-08-24 00:00:00-03:00  97.639999  97.809998  97.300003  97.440002   19252
# 2023-08-25 00:00:00-03:00  97.400002  97.879997  97.400002  97.699997   15236
# 2023-08-28 00:00:00-03:00  97.690002  97.739998  97.400002  97.589996    6496
#
# ...

# %%
import csv
# grava arquivo CSV usando Library CSV

with open("Grv_Ticker.csv", "w", newline='\n' ) as arquivo:
     arquivo_head=['Data', 'Fechamento','Volume','Dividendos']  # cria header do arquivo
     writer = csv.DictWriter(arquivo, fieldnames=arquivo_head)
     writer.writeheader()                                       # escreve header no arquivo
     
     # escreve linhas no arquivo
     writer.writerow({ 'Data'       :"2023-08-22 00:00:00-03:00"
                      ,'Fechamento' : 97.900002
                      ,'Volume'     : 13683
                      ,'Dividendos' : 0.0  })
     
     
 # arquivo.write("teste de escrita")

# %%
# grava em arquivo CSV o DataFrame
# grava arquivo CSV usando Library pandas

dfWrite= Myhist.to_csv(path_or_buf='Grv_buf.csv', sep=';')
